# %%
from urllib.request import urlopen
import requests
import bs4
import pandas as pd
def lent_data(DEAL_YMD ,LAWD_CD):
    endpoint= "http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?"
    serviceKey = "iBEI9PHF2CVq9qPxkxcVWZ3b%2BiT5hynqSdTZNmU%2FBgD%2FrAw4ApwMSxxWZVlEHHWtTkaUnVJaFccuEgRivMtxfg%3D%3D"
    paramset = "serviceKey="+serviceKey + "&" + "LAWD_CD=" + LAWD_CD + "&" + "DEAL_YMD=" + DEAL_YMD 
    url=endpoint+paramset
    resultXML = urlopen(url)
    result = resultXML.read()
    xmlsoup = bs4.BeautifulSoup(result, 'lxml-xml')
    Item=xmlsoup.findAll("item")
    lent=pd.DataFrame()
 
    for t in Item:
        build=t.find("건축년도").text
        year=t.find("년").text
        month=t.find("월").text
        day=t.find("일").text
        dong=t.find("법정동").text
        deposit=t.find("보증금액").text
        month_price=t.find("월세금액").text
        apart=t.find("아파트").text
        size=t.find("전용면적").text
        try:
            ji_num=t.find("지번").text
        except:
            ji_num=""
        ji_code=t.find("지역코드").text
        floor=t.find("층").text
 
        temp = pd.DataFrame(([[build,year,month,day,dong,deposit,month_price,apart,size,ji_num,ji_code,floor]]), columns=["build","year","month","day","dong","deposit","month_price","apart","size","ji_num","ji_code","floor"])
        lent=pd.concat([lent,temp])
 
    lent=lent.reset_index(drop=True)
    return lent

# %%
from urllib.request import urlopen
import requests
import bs4
import pandas as pd
if __name__ == "__main__":
    code=pd.read_excel("KIKcd_B.20180122.xlsx")
    code_con=code[(code["시도명"]=="서울특별시") | (code["시도명"]=="부산광역시")|(code["시도명"]=="대구광역시")|(code["시도명"]=="인천광역시")|(code["시도명"]=="광주광역시")|(code["시도명"]=="대전광역시")|(code["시도명"]=="울산광역시")|(code["시도명"]=="광주광역시") |(code["시도명"]=="경기도")]
    code_con=code_con[code_con["읍면동명"].isnull()==True]
    code_con=code_con[code_con["시군구명"].isnull()==False]
    code_con["ji_code"]=code_con["법정동코드"].astype(str).str[0:5]
    lent_trade=pd.DataFrame()
 
    YMD=list(["201705","201706","201707","201708","201709","201710","201711","201712","201801","201802","201803","201804","201805","201806","201807","201808","201809","201810","201811","201812","201901","201902","201903","201904","201905","201906","201907","201908","201909","201910","201911","201912"])
    for m in YMD:
        for c in code_con["ji_code"]:
            temp=lent_data(m,c)
            lent_trade=pd.concat([lent_trade,temp])
        print("*"+str(m)+"가 검색 되었습니다.")
lent_trade.to_csv('Dataset.csv',encoding="euc-kr")
# Out:
# *201705가 검색 되었습니다.
# *201706가 검색 되었습니다.
# *201707가 검색 되었습니다.
# *201708가 검색 되었습니다.
# *201709가 검색 되었습니다.
# *201710가 검색 되었습니다.
# *201711가 검색 되었습니다.
# *201712가 검색 되었습니다.
# *201801가 검색 되었습니다.
# *201802가 검색 되었습니다.
# *201803가 검색 되었습니다.
# *201804가 검색 되었습니다.
# *201805가 검색 되었습니다.
# *201806가 검색 되었습니다.
# *201807가 검색 되었습니다.
# *201808가 검색 되었습니다.
# *201809가 검색 되었습니다.
# *201810가 검색 되었습니다.
# *201811가 검색 되었습니다.
# *201812가 검색 되었습니다.
# *201901가 검색 되었습니다.
# *201902가 검색 되었습니다.
# *201903가 검색 되었습니다.
# *201904가 검색 되었습니다.
# *201905가 검색 되었습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6a0fe33397ec> in <module>
#      14     for m in YMD:
#      15         for c in code_con["ji_code"]:
# ---> 16             temp=lent_data(m,c)
#      17             lent_trade=pd.concat([lent_trade,temp])
#      18         print("*"+str(m)+"가 검색 되었습니다.")
#
# <ipython-input-3-725bfeba726e> in lent_data(DEAL_YMD, LAWD_CD)
#       8     paramset = "serviceKey="+serviceKey + "&" + "LAWD_CD=" + LAWD_CD + "&" + "DEAL_YMD=" + DEAL_YMD
#       9     url=endpoint+paramset
# ---> 10     resultXML = urlopen(url)
#      11     result = resultXML.read()
#      12     xmlsoup = bs4.BeautifulSoup(result, 'lxml-xml')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#     934         """Connect to the host and port specified in __init__."""
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     938
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# KeyboardInterrupt:

# %%
lent_trade
# Out:
#    build  year month day   dong     deposit month_price  \
# 0   2008  2017     5   1    사직동      73,000           0
# 1   2008  2017     5   2    사직동      50,000         150
# 2   2008  2017     5   8    사직동         600         300
# 3   2008  2017     5  10    사직동      65,000          80
# 4   2008  2017     5  11    사직동      30,000         100
# 5   2008  2017     5  17    사직동      80,000           0
# 6   2008  2017     5  18    사직동      66,000           0
# 7   1974  2017     5  24    사직동      28,000           0
# 8   2008  2017     5  25    사직동      75,000           0
# 9   2008  2017     5  29    사직동      30,000         150
# 10  2004  2017     5   2    내수동      65,000          60
# 11  2004  2017     5  18    내수동      80,000           0
# 12  2004  2017     5  30    내수동      68,000           0
# 13  2006  2017     5   1    인의동      38,000           0
# 14  2006  2017     5  11    인의동      43,000           0
# 15  2006  2017     5  30    인의동      44,000           0
# 16  2017  2017     5   1    효제동       3,000          70
# 17  2017  2017     5  13    효제동       3,000          55
# 18  2002  2017     5  20   명륜1가      40,000           0
# 19  1999  2017     5  11   명륜2가      31,000           0
# 20  1999  2017     5  23   명륜2가      15,000         110
# 21  1995  2017     5  26   명륜2가      58,000           0
# 22  1996  2017     5  26   명륜2가      49,000           0
# 23  1995  2017     5  29   명륜2가      56,000           0
# 24  1992  2017     5   3    창신동      30,000           0
# 25  1992  2017     5   5    창신동      27,000           0
# 26  1992  2017     5   5    창신동      35,000           0
# 27  1992  2017     5   6    창신동      30,000           0
# 28  1993  2017     5   9    창신동      21,000          10
# 29  1992  2017     5   9    창신동      32,000           0
# ..   ...   ...   ...  ..    ...         ...         ...
# 11  2005  2017    12  27    비산동      20,000           0
# 12  2016  2017    12  28    비산동      15,000           0
# 13  1982  2017    12  30    비산동       7,000           0
# 14  2009  2017    12   1    평리동      10,000           0
# 15  2009  2017    12   1    평리동      25,000           0
# 16  2011  2017    12   4    평리동      20,000           0
# 17  2011  2017    12   4    평리동      26,000           0
# 18  1980  2017    12   9    평리동      10,000           0
# 19  2011  2017    12  11    평리동       1,000          67
# 20  2011  2017    12  19    평리동      23,000           0
# 21  2011  2017    12  19    평리동      25,000           0
# 22  2011  2017    12  23    평리동      24,000           0
# 23  2011  2017    12  25    평리동      24,000           0
# 24  2011  2017    12  26    평리동      21,000           0
# 25  2011  2017    12  28    평리동      22,000           0
# 26  2011  2017    12  29    평리동      20,000           0
# 27  2009  2017    12   2    중리동      25,000           0
# 28  2009  2017    12   6    중리동       5,000          40
# 29  2009  2017    12   7    중리동       3,000          67
# 30  1981  2017    12   7    중리동       6,000           0
# 31  2009  2017    12   7    중리동      20,000           0
# 32  1983  2017    12  11    중리동       8,500           0
# 33  1997  2017    12  12    중리동       7,500           0
# 34  2009  2017    12  13    중리동      27,000           0
# 35  2009  2017    12  16    중리동      19,000           0
# 36  1982  2017    12  20    중리동       7,500           0
# 37  2009  2017    12  23    중리동      27,000           0
# 38  1981  2017    12  28    중리동      10,000           0
# 39  2009  2017    12  30    중리동      10,000          54
# 40  2009  2017    12  30    중리동      26,000           0
#
#                     apart     size  ji_num ji_code floor
# 0   광화문풍림스페이스본(101동~105동)   108.55       9   11110     1
# 1   광화문풍림스페이스본(101동~105동)   147.31       9   11110     8
# 2        광화문풍림스페이스본(106동)   153.42     9-1   11110     5
# 3   광화문풍림스페이스본(101동~105동)   159.01       9   11110     8
# 4   광화문풍림스페이스본(101동~105동)     70.8       9   11110    10
# 5   광화문풍림스페이스본(101동~105동)   146.92       9   11110    12
# 6   광화문풍림스페이스본(101동~105동)    94.28       9   11110     1
# 7                   사직아파트   116.23     1-8   11110     6
# 8   광화문풍림스페이스본(101동~105동)   146.92       9   11110     5
# 9        광화문풍림스페이스본(106동)   153.42     9-1   11110    11
# 10              경희궁의아침4단지   150.77      73   11110     4
# 11              경희궁의아침2단지   124.17      71   11110     3
# 12              경희궁의아침4단지   124.17      73   11110    14
# 13                효성쥬얼리시티    84.64    48-2   11110    18
# 14                효성쥬얼리시티    84.64    48-2   11110    13
# 15                효성쥬얼리시티    98.39    48-2   11110    10
# 16                포레스트힐시티  20.5523    65-2   11110    10
# 17                포레스트힐시티  14.1832    65-2   11110     9
# 18                   아마레스    72.61    45-5   11110     7
# 19                    아남3    44.37     237   11110     8
# 20                    아남3    65.78     237   11110     4
# 21                    아남1     84.9       4   11110    17
# 22                    아남2    84.96     236   11110     5
# 23                    아남1     84.9       4   11110     6
# 24                  창신쌍용1    79.87     702   11110     1
# 25                  창신쌍용1    79.87     702   11110    13
# 26                  창신쌍용1   106.62     702   11110     1
# 27                  창신쌍용1    79.87     702   11110    11
# 28                  창신쌍용2    79.87     703   11110     4
# 29                  창신쌍용1    79.87     702   11110    14
# ..                    ...      ...     ...     ...   ...
# 11                 한신휴플러스  93.7278     315   27170    13
# 12              양문그레이스 A동  84.4327    1455   27170     7
# 13                     양지    56.48  1199-7   27170     5
# 14                 평리롯데캐슬  84.9639    1676   27170    10
# 15                 평리롯데캐슬  84.9639    1676   27170     6
# 16                 평리푸르지오  84.9305    1680   27170    10
# 17                 평리푸르지오  84.9203    1680   27170    14
# 18                평리광명아파트    82.25   619-1   27170     3
# 19                 평리푸르지오  59.8925    1680   27170    14
# 20                 평리푸르지오  84.9203    1680   27170    15
# 21                 평리푸르지오  84.9203    1680   27170    18
# 22                 평리푸르지오  84.9203    1680   27170    16
# 23                 평리푸르지오  84.9203    1680   27170     1
# 24                 평리푸르지오  59.8925    1680   27170     2
# 25                 평리푸르지오  59.8925    1680   27170     3
# 26                 평리푸르지오  59.8925    1680   27170     8
# 27                 중리롯데캐슬   84.984    26-1   27170     6
# 28                 중리롯데캐슬   84.984    26-1   27170    10
# 29                 중리롯데캐슬   74.663    26-1   27170     7
# 30                    꽃동네   51.285   121-1   27170     2
# 31                 중리롯데캐슬   59.979    26-1   27170    16
# 32                   진달래2    56.34    42-1   27170     2
# 33               중리동다산하트빌    46.35   115-5   27170     3
# 34                 중리롯데캐슬  100.696    26-1   27170     4
# 35                 중리롯데캐슬   59.979    26-1   27170     7
# 36                    신세계  56.5975   108-1   27170     2
# 37                 중리롯데캐슬  115.687    26-1   27170    20
# 38                    꽃동네   66.645   121-1   27170     5
# 39                 중리롯데캐슬  100.696    26-1   27170    10
# 40                 중리롯데캐슬  115.687    26-1   27170    12
#
# [288948 rows x 12 columns]
